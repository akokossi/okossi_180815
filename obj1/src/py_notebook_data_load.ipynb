# %% [markdown]
# #### JP Morgan Institute Capstone Project: Uploading data to Spark/Linux testing environment in Databricks
#   - File was in Excel
#   - File was saved as csv ile

# %%
display(dbutils.fs.ls("/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/mytest_table/</td><td>mytest_table/</td><td>0</td></tr><tr><td>dbfs:/temp_mytest_table/</td><td>temp_mytest_table/</td><td>0</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("/FileStore/tables/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/jpmc_rse_assignment_data.csv</td><td>jpmc_rse_assignment_data.csv</td><td>5008101</td></tr><tr><td>dbfs:/FileStore/tables/mytest_table/</td><td>mytest_table/</td><td>0</td></tr></tbody></table></div>

# %%
from pyspark.sql import *
from pyspark.sql.types import *

schema = StructType([
StructField('ER30000',DoubleType()),
StructField('ER30001',DoubleType()),
StructField('ER30002',DoubleType()),
StructField('ER34101',DoubleType()),
StructField('ER34102',DoubleType()),
StructField('ER34103',DoubleType()),
StructField('ER34104',DoubleType()),
StructField('ER34105',DoubleType()),
StructField('ER34106',DoubleType()),
StructField('ER34107',DoubleType()),
StructField('ER34108',DoubleType()),
StructField('ER34109',DoubleType()),
StructField('ER34110',DoubleType()),
StructField('ER34111',DoubleType()),
StructField('ER34112',DoubleType()),
StructField('ER34113',DoubleType()),
StructField('ER34114',DoubleType()),
StructField('ER34115',DoubleType()),
StructField('ER34116',DoubleType()),
StructField('ER34117',DoubleType()),
StructField('ER34118',DoubleType()),
StructField('ER34119',DoubleType()),
StructField('ER34120',DoubleType()),
StructField('ER34121',DoubleType()),
StructField('ER34122',DoubleType()),
StructField('ER34123',DoubleType()),
StructField('ER34124',DoubleType()),
StructField('ER34125',DoubleType()),
StructField('ER34126',DoubleType()),
StructField('ER34127',DoubleType()),
StructField('ER34128',DoubleType()),
StructField('ER34129',DoubleType()),
StructField('ER34130',DoubleType()),
StructField('ER34131',DoubleType()),
StructField('ER34132',DoubleType()),
StructField('ER34133',DoubleType()),
StructField('ER34134',DoubleType()),
StructField('ER34135',DoubleType()),
StructField('ER34136',DoubleType()),
StructField('ER34137',DoubleType()),
StructField('ER34138',DoubleType()),
StructField('ER34139',DoubleType()),
StructField('ER34140',DoubleType()),
StructField('ER34141',DoubleType()),
StructField('ER34142',DoubleType()),
StructField('ER34143',DoubleType()),
StructField('ER34144',DoubleType()),
StructField('ER34144A',DoubleType()),
StructField('ER34144B',DoubleType()),
StructField('ER34144C',DoubleType()),
StructField('ER34144D',DoubleType()),
StructField('ER34144E',DoubleType()),
StructField('ER34145',DoubleType()),
StructField('ER34146',DoubleType()),
StructField('ER34147',DoubleType()),
StructField('ER34148',DoubleType()),
StructField('ER34149',DoubleType()),
StructField('ER34150',DoubleType()),
StructField('ER34151',DoubleType()),
StructField('ER34152',DoubleType()),
StructField('ER34153',DoubleType()),
StructField('ER34154',DoubleType()),
StructField('ER34155',DoubleType()),
StructField('ER34201',DoubleType()),
StructField('ER34202',DoubleType()),
StructField('ER34203',DoubleType()),
StructField('ER34204',DoubleType()),
StructField('ER34205',DoubleType()),
StructField('ER34206',DoubleType()),
StructField('ER34207',DoubleType()),
StructField('ER34208',DoubleType()),
StructField('ER34209',DoubleType()),
StructField('ER34210',DoubleType()),
StructField('ER34211',DoubleType())
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### Read the uploaded CSV file

# %%
df=spark.read.csv("dbfs:/FileStore/tables/jpmc_rse_assignment_data.csv", header=True, mode="DROPMALFORMED")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import *

df=df.withColumn('ER30000',df['ER30000'].cast(DoubleType()))
df=df.withColumn('ER30001',df['ER30001'].cast(DoubleType()))
df=df.withColumn('ER30002',df['ER30002'].cast(DoubleType()))
df=df.withColumn('ER34101',df['ER34101'].cast(DoubleType()))
df=df.withColumn('ER34102',df['ER34102'].cast(DoubleType()))
df=df.withColumn('ER34103',df['ER34103'].cast(DoubleType()))
df=df.withColumn('ER34104',df['ER34104'].cast(DoubleType()))
df=df.withColumn('ER34105',df['ER34105'].cast(DoubleType()))
df=df.withColumn('ER34106',df['ER34106'].cast(DoubleType()))
df=df.withColumn('ER34107',df['ER34107'].cast(DoubleType()))
df=df.withColumn('ER34108',df['ER34108'].cast(DoubleType()))
df=df.withColumn('ER34109',df['ER34109'].cast(DoubleType()))
df=df.withColumn('ER34110',df['ER34110'].cast(DoubleType()))
df=df.withColumn('ER34111',df['ER34111'].cast(DoubleType()))
df=df.withColumn('ER34112',df['ER34112'].cast(DoubleType()))
df=df.withColumn('ER34113',df['ER34113'].cast(DoubleType()))
df=df.withColumn('ER34114',df['ER34114'].cast(DoubleType()))
df=df.withColumn('ER34115',df['ER34115'].cast(DoubleType()))
df=df.withColumn('ER34116',df['ER34116'].cast(DoubleType()))
df=df.withColumn('ER34117',df['ER34117'].cast(DoubleType()))
df=df.withColumn('ER34118',df['ER34118'].cast(DoubleType()))
df=df.withColumn('ER34119',df['ER34119'].cast(DoubleType()))
df=df.withColumn('ER34120',df['ER34120'].cast(DoubleType()))
df=df.withColumn('ER34121',df['ER34121'].cast(DoubleType()))
df=df.withColumn('ER34122',df['ER34122'].cast(DoubleType()))
df=df.withColumn('ER34123',df['ER34123'].cast(DoubleType()))
df=df.withColumn('ER34124',df['ER34124'].cast(DoubleType()))
df=df.withColumn('ER34125',df['ER34125'].cast(DoubleType()))
df=df.withColumn('ER34126',df['ER34126'].cast(DoubleType()))
df=df.withColumn('ER34127',df['ER34127'].cast(DoubleType()))
df=df.withColumn('ER34128',df['ER34128'].cast(DoubleType()))
df=df.withColumn('ER34129',df['ER34129'].cast(DoubleType()))
df=df.withColumn('ER34130',df['ER34130'].cast(DoubleType()))
df=df.withColumn('ER34131',df['ER34131'].cast(DoubleType()))
df=df.withColumn('ER34132',df['ER34132'].cast(DoubleType()))
df=df.withColumn('ER34133',df['ER34133'].cast(DoubleType()))
df=df.withColumn('ER34134',df['ER34134'].cast(DoubleType()))
df=df.withColumn('ER34135',df['ER34135'].cast(DoubleType()))
df=df.withColumn('ER34136',df['ER34136'].cast(DoubleType()))
df=df.withColumn('ER34137',df['ER34137'].cast(DoubleType()))
df=df.withColumn('ER34138',df['ER34138'].cast(DoubleType()))
df=df.withColumn('ER34139',df['ER34139'].cast(DoubleType()))
df=df.withColumn('ER34140',df['ER34140'].cast(DoubleType()))
df=df.withColumn('ER34141',df['ER34141'].cast(DoubleType()))
df=df.withColumn('ER34142',df['ER34142'].cast(DoubleType()))
df=df.withColumn('ER34143',df['ER34143'].cast(DoubleType()))
df=df.withColumn('ER34144',df['ER34144'].cast(DoubleType()))
df=df.withColumn('ER34144A',df['ER34144A'].cast(DoubleType()))
df=df.withColumn('ER34144B',df['ER34144B'].cast(DoubleType()))
df=df.withColumn('ER34144C',df['ER34144C'].cast(DoubleType()))
df=df.withColumn('ER34144D',df['ER34144D'].cast(DoubleType()))
df=df.withColumn('ER34144E',df['ER34144E'].cast(DoubleType()))
df=df.withColumn('ER34145',df['ER34145'].cast(DoubleType()))
df=df.withColumn('ER34146',df['ER34146'].cast(DoubleType()))
df=df.withColumn('ER34147',df['ER34147'].cast(DoubleType()))
df=df.withColumn('ER34148',df['ER34148'].cast(DoubleType()))
df=df.withColumn('ER34149',df['ER34149'].cast(DoubleType()))
df=df.withColumn('ER34150',df['ER34150'].cast(DoubleType()))
df=df.withColumn('ER34151',df['ER34151'].cast(DoubleType()))
df=df.withColumn('ER34152',df['ER34152'].cast(DoubleType()))
df=df.withColumn('ER34153',df['ER34153'].cast(DoubleType()))
df=df.withColumn('ER34154',df['ER34154'].cast(DoubleType()))
df=df.withColumn('ER34155',df['ER34155'].cast(DoubleType()))
df=df.withColumn('ER34201',df['ER34201'].cast(DoubleType()))
df=df.withColumn('ER34202',df['ER34202'].cast(DoubleType()))
df=df.withColumn('ER34203',df['ER34203'].cast(DoubleType()))
df=df.withColumn('ER34204',df['ER34204'].cast(DoubleType()))
df=df.withColumn('ER34205',df['ER34205'].cast(DoubleType()))
df=df.withColumn('ER34206',df['ER34206'].cast(DoubleType()))
df=df.withColumn('ER34207',df['ER34207'].cast(DoubleType()))
df=df.withColumn('ER34208',df['ER34208'].cast(DoubleType()))
df=df.withColumn('ER34209',df['ER34209'].cast(DoubleType()))
df=df.withColumn('ER34210',df['ER34210'].cast(DoubleType()))
df=df.withColumn('ER34211',df['ER34211'].cast(DoubleType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.write.mode("overwrite").saveAsTable("jpmc_rse_assignment_data_csv_test")
df.registerTempTable("jpmc_rse_assignment_data_temp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select * from jpmc_rse_assignment_data_temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
